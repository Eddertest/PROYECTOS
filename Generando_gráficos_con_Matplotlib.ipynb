# %% [markdown]
# <a href="https://colab.research.google.com/github/Eddertest/PROYECTOS/blob/main/Generando_gr%C3%A1ficos_con_Matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Generando gráficos con Matplotlib

# %%
import matplotlib.pyplot as plt
valores=[5,4,3,2,1,0,2,4,4,5]
valores2=[1,1,1,1,1,1,1,1,1]
plt.plot(valores, label="plot1")
plt.plot(valores2, label="plot2")
plt.legend()
plt.style.use("ggplot")
plt.title("Grafico")
# Out:
# Text(0.5, 1.0, 'Grafico')
